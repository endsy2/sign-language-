# %%
# !pip install tensorflow mediapipe opencv-python numpy
# Out:
# Requirement already satisfied: tensorflow in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (2.15.0)
# Requirement already satisfied: mediapipe in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (0.10.10)
# Requirement already satisfied: opencv-python in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (4.5.5.64)
# Requirement already satisfied: numpy in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (1.26.4)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.15.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.15.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.41.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.10)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.1.3)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.6.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from mediapipe) (25.4.0)
# Requirement already satisfied: jax in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from mediapipe) (0.4.34)
# Requirement already satisfied: matplotlib in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from mediapipe) (3.10.7)
# Requirement already satisfied: opencv-contrib-python in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from mediapipe) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.45.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.3.1)
# Requirement already satisfied: CFFI>=1.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.23)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.0.3)
# Requirement already satisfied: jaxlib<=0.4.34,>=0.4.34 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from jax->mediapipe) (0.4.34)
# Requirement already satisfied: scipy>=1.10 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from jax->mediapipe) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from matplotlib->mediapipe) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from matplotlib->mediapipe) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from matplotlib->mediapipe) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from matplotlib->mediapipe) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kongm\pycharmprojects\signlanguage\.venv3\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)

# %%
import cv2
import numpy as np
import os
import mediapipe as mp
from IPython.display import clear_output
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import time
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
import tensorflow as tf

# %%
import cv2
import numpy as np
import mediapipe as mp
import os
import time
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# ===============================
# SETTINGS
# ===============================
DATA_PATH = "data"
SIGNS = ["Thank You","Hello"]  # change or add more signs
NUM_SEQUENCES = 50
SEQUENCE_LENGTH = 30
FRAME_WIDTH = 1280
FRAME_HEIGHT = 720
COUNTDOWN_START = 3
MIN_VALID_FRAMES = 20
FEATURES = 126

# ===============================
# MEDIA PIPE SETUP
# ===============================
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

# ===============================
# UTILITY FUNCTIONS
# ===============================
def extract_hand_keypoints(results):
    lh = np.zeros(21*3)
    rh = np.zeros(21*3)
    if results.left_hand_landmarks:
        lh = np.array([[lm.x, lm.y, lm.z] for lm in results.left_hand_landmarks.landmark]).flatten()
    if results.right_hand_landmarks:
        rh = np.array([[lm.x, lm.y, lm.z] for lm in results.right_hand_landmarks.landmark]).flatten()
    return np.concatenate([lh, rh])

def create_folders(signs):
    for sign in signs:
        os.makedirs(os.path.join(DATA_PATH, sign), exist_ok=True)

def display_countdown(frame, countdown, sign_name, sequence_num):
    overlay = frame.copy()
    cv2.putText(overlay, f"{countdown}", (FRAME_WIDTH//2 - 50, FRAME_HEIGHT//2),
                cv2.FONT_HERSHEY_SIMPLEX, 5, (0, 0, 255), 10)
    cv2.putText(overlay, f"{sign_name} | Sequence {sequence_num+1}/{NUM_SEQUENCES}",
                (30, 60), cv2.FONT_HERSHEY_SIMPLEX, 1.2, (255, 255, 0), 3)
    return cv2.addWeighted(overlay, 0.7, frame, 0.3, 0)

def collect_sequence(cap, holistic, sign_name, seq_num):
    sequence = []
    frame_num = 0
    while frame_num < SEQUENCE_LENGTH:
        ret, frame = cap.read()
        if not ret:
            continue

        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = holistic.process(image)

        if results.left_hand_landmarks:
            mp_drawing.draw_landmarks(frame, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
        if results.right_hand_landmarks:
            mp_drawing.draw_landmarks(frame, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

        keypoints = extract_hand_keypoints(results)

        if np.any(keypoints != 0):
            sequence.append(keypoints)
            frame_num += 1

        cv2.putText(frame, f"Collecting: {sign_name}", (30, 50),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 3)
        cv2.putText(frame, f"Sequence {seq_num+1}/{NUM_SEQUENCES} | Frame {frame_num}/{SEQUENCE_LENGTH}",
                    (30, 100), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 255, 255), 2)
        cv2.imshow("Sign Data Collection", frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            raise KeyboardInterrupt

    if len(sequence) < MIN_VALID_FRAMES:
        print(f"Warning: Sequence {seq_num+1} for '{sign_name}' too short ({len(sequence)} frames). Skipping.")
        return None

    if len(sequence) < SEQUENCE_LENGTH:
        pad_len = SEQUENCE_LENGTH - len(sequence)
        padding = np.zeros((pad_len, FEATURES))
        sequence = np.vstack([sequence, padding])

    return sequence

# ===============================
# MAIN COLLECTION + PREPARE DATA
# ===============================
def collect_and_prepare_data(cap, signs):
    create_folders(signs)
    sequences = []
    labels = []

    # Load existing data first
    for sign in signs:
        action_path = os.path.join(DATA_PATH, sign)
        if os.path.exists(action_path):
            files = sorted(os.listdir(action_path))
            for file in files:
                file_path = os.path.join(action_path, file)
                seq = np.load(file_path)
                sequences.append(seq)
                labels.append(signs.index(sign))

    # Start new collection
    with mp_holistic.Holistic(min_detection_confidence=0.6,
                              min_tracking_confidence=0.6) as holistic:
        for sign in signs:
            print(f"\nStarting new collection for sign: {sign}")
            time.sleep(1)
            for seq in range(NUM_SEQUENCES):
                # Countdown
                for countdown in range(COUNTDOWN_START, 0, -1):
                    ret, frame = cap.read()
                    if not ret:
                        continue
                    overlay_frame = display_countdown(frame, countdown, sign, seq)
                    cv2.imshow("Sign Data Collection", overlay_frame)
                    cv2.waitKey(800)

                # Collect sequence
                sequence = collect_sequence(cap, holistic, sign, seq)
                if sequence is not None:
                    file_path = os.path.join(DATA_PATH, sign, f"new_{int(time.time())}_{seq}.npy")
                    np.save(file_path, sequence)
                    print(f"Saved new {sign} sequence {seq+1}/{NUM_SEQUENCES}")

                    sequences.append(sequence)
                    labels.append(signs.index(sign))

    # Convert to arrays
    sequences = np.array(sequences)
    labels = np.array(labels)

    # Split dataset
    X_train, X_test, y_train, y_test = train_test_split(
        sequences, labels, test_size=0.2, random_state=42, shuffle=True
    )

    # One-hot encode labels
    y_train = to_categorical(y_train, num_classes=len(signs))
    y_test = to_categorical(y_test, num_classes=len(signs))

    return X_train, X_test, y_train, y_test

# ===============================
# RUN EVERYTHING
# ===============================
cap = cv2.VideoCapture(0)
cap.set(3, FRAME_WIDTH)
cap.set(4, FRAME_HEIGHT)

try:
    X_train, X_test, y_train, y_test = collect_and_prepare_data(cap, SIGNS)
except KeyboardInterrupt:
    print("\nCollection interrupted by user.")

cap.release()
cv2.destroyAllWindows()
print("Data collection and preparation complete!")
print(f"Training samples: {len(X_train)}, Testing samples: {len(X_test)}")
# Out:
# Starting new collection for sign: Thank You
# Saved new Thank You sequence 1/1
#
# Starting new collection for sign: Hello
# Saved new Hello sequence 1/1
# Data collection and preparation complete!
# Training samples: 76, Testing samples: 20

# %%
import os
import numpy as np
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# ===============================
# SETTINGS
# ===============================
DATA_PATH = "data"
SEQUENCE_LENGTH = 30
MIN_VALID_FRAMES = 20
FEATURES = 126

# ===============================
# LOAD & CLEAN DATA
# ===============================
actions = sorted(os.listdir(DATA_PATH))
label_map = {action: idx for idx, action in enumerate(actions)}

sequences = []
labels = []

for action in actions:
    action_path = os.path.join(DATA_PATH, action)
    files = sorted(os.listdir(action_path))
    for file in files:
        file_path = os.path.join(action_path, file)
        seq = np.load(file_path)

        # Remove invalid sequences
        if seq.shape[0] < MIN_VALID_FRAMES or np.all(seq == 0):
            print(f"Deleting invalid sequence: {file_path}")
            os.remove(file_path)
            continue

        # Pad if too short
        if seq.shape[0] < SEQUENCE_LENGTH:
            pad_len = SEQUENCE_LENGTH - seq.shape[0]
            seq = np.vstack([seq, np.zeros((pad_len, FEATURES))])

        sequences.append(seq)
        labels.append(label_map[action])

# Convert to arrays
sequences = np.array(sequences)
labels = np.array(labels)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    sequences, labels, test_size=0.2, random_state=42, shuffle=True
)

# One-hot encode labels
y_train = to_categorical(y_train, num_classes=len(actions))
y_test = to_categorical(y_test, num_classes=len(actions))

print(f"Actions: {actions}")
print(f"Training samples: {len(X_train)}, Testing samples: {len(X_test)}")
# Out:
# Actions: ['Hello', 'No', 'Thank You', 'Yes']
# Training samples: 171, Testing samples: 43

# %%
# ===============================
# LSTM MODEL
# ===============================
model = Sequential()

# First LSTM layer
model.add(LSTM(128, return_sequences=True, activation='relu', input_shape=(30, sequences.shape[2])))
model.add(Dropout(0.2))
model.add(BatchNormalization())

# Second LSTM layer
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())

# Dense layer
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))

# Output layer
model.add(Dense(len(actions), activation='softmax'))

# Compile
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\kongm\PycharmProjects\SignLanguage\.venv3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 128)           130560
#
#  dropout (Dropout)           (None, 30, 128)           0
#
#  batch_normalization (Batch  (None, 30, 128)           512
#  Normalization)
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  batch_normalization_1 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 185156 (723.27 KB)
# Trainable params: 184772 (721.77 KB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=200, validation_data=(X_test, y_test))
# Out:
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\kongm\PycharmProjects\SignLanguage\.venv3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\kongm\PycharmProjects\SignLanguage\.venv3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 6/6 [==============================] - 2s 81ms/step - loss: 1.4617 - accuracy: 0.3626 - val_loss: 1.3634 - val_accuracy: 0.4186
# Epoch 2/200
# 6/6 [==============================] - 0s 23ms/step - loss: 1.1060 - accuracy: 0.4912 - val_loss: 1.3504 - val_accuracy: 0.4884
# Epoch 3/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.0241 - accuracy: 0.5497 - val_loss: 1.3304 - val_accuracy: 0.5349
# Epoch 4/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.8178 - accuracy: 0.7310 - val_loss: 1.3185 - val_accuracy: 0.4651
# Epoch 5/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.7517 - accuracy: 0.7427 - val_loss: 1.3236 - val_accuracy: 0.3953
# Epoch 6/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5334 - accuracy: 0.8596 - val_loss: 1.3316 - val_accuracy: 0.4651
# Epoch 7/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4575 - accuracy: 0.8830 - val_loss: 1.3142 - val_accuracy: 0.4419
# Epoch 8/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3804 - accuracy: 0.8947 - val_loss: 1.3091 - val_accuracy: 0.4186
# Epoch 9/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4275 - accuracy: 0.8889 - val_loss: 1.3359 - val_accuracy: 0.3256
# Epoch 10/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3478 - accuracy: 0.9123 - val_loss: 1.3322 - val_accuracy: 0.3488
# Epoch 11/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4036 - accuracy: 0.8889 - val_loss: 1.3289 - val_accuracy: 0.2791
# Epoch 12/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3350 - accuracy: 0.9181 - val_loss: 1.3327 - val_accuracy: 0.2791
# Epoch 13/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3073 - accuracy: 0.9006 - val_loss: 1.3341 - val_accuracy: 0.3023
# Epoch 14/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2747 - accuracy: 0.9064 - val_loss: 1.2998 - val_accuracy: 0.5349
# Epoch 15/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1961 - accuracy: 0.9766 - val_loss: 1.2647 - val_accuracy: 0.3256
# Epoch 16/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2784 - accuracy: 0.9532 - val_loss: 1.2264 - val_accuracy: 0.5349
# Epoch 17/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3922 - accuracy: 0.9064 - val_loss: 1.2751 - val_accuracy: 0.3256
# Epoch 18/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.2593 - accuracy: 0.9298 - val_loss: 1.2371 - val_accuracy: 0.4651
# Epoch 19/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1668 - accuracy: 0.9649 - val_loss: 1.2215 - val_accuracy: 0.4884
# Epoch 20/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2651 - accuracy: 0.9240 - val_loss: 1.1410 - val_accuracy: 0.6279
# Epoch 21/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1832 - accuracy: 0.9532 - val_loss: 1.0633 - val_accuracy: 0.7442
# Epoch 22/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1677 - accuracy: 0.9649 - val_loss: 0.9639 - val_accuracy: 0.7907
# Epoch 23/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.1567 - accuracy: 0.9591 - val_loss: 0.8804 - val_accuracy: 0.7907
# Epoch 24/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.1759 - accuracy: 0.9474 - val_loss: 0.9234 - val_accuracy: 0.7209
# Epoch 25/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1039 - accuracy: 0.9942 - val_loss: 0.9831 - val_accuracy: 0.6279
# Epoch 26/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1234 - accuracy: 0.9649 - val_loss: 0.9416 - val_accuracy: 0.7442
# Epoch 27/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1460 - accuracy: 0.9649 - val_loss: 1.1631 - val_accuracy: 0.4884
# Epoch 28/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4666 - accuracy: 0.8596 - val_loss: 1.4169 - val_accuracy: 0.4651
# Epoch 29/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2081 - accuracy: 0.9357 - val_loss: 0.8050 - val_accuracy: 0.6977
# Epoch 30/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2820 - accuracy: 0.9064 - val_loss: 0.7825 - val_accuracy: 0.8140
# Epoch 31/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2880 - accuracy: 0.8830 - val_loss: 0.9339 - val_accuracy: 0.6977
# Epoch 32/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1721 - accuracy: 0.9649 - val_loss: 0.6963 - val_accuracy: 0.9302
# Epoch 33/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1910 - accuracy: 0.9240 - val_loss: 0.5766 - val_accuracy: 0.9302
# Epoch 34/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3039 - accuracy: 0.8947 - val_loss: 0.9528 - val_accuracy: 0.4884
# Epoch 35/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2030 - accuracy: 0.9474 - val_loss: 0.8602 - val_accuracy: 0.6744
# Epoch 36/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.6360 - accuracy: 0.7719 - val_loss: 0.6368 - val_accuracy: 0.8372
# Epoch 37/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5798 - accuracy: 0.7836 - val_loss: 3.9466 - val_accuracy: 0.3721
# Epoch 38/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4294 - accuracy: 0.8655 - val_loss: 1.5206 - val_accuracy: 0.4419
# Epoch 39/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4067 - accuracy: 0.8830 - val_loss: 0.9442 - val_accuracy: 0.7209
# Epoch 40/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2612 - accuracy: 0.9123 - val_loss: 1.3294 - val_accuracy: 0.4186
# Epoch 41/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.1666 - accuracy: 0.9532 - val_loss: 1.3465 - val_accuracy: 0.5581
# Epoch 42/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.1352 - accuracy: 0.9532 - val_loss: 1.3682 - val_accuracy: 0.4884
# Epoch 43/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2729 - accuracy: 0.9240 - val_loss: 1.2909 - val_accuracy: 0.5116
# Epoch 44/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.2070 - accuracy: 0.9181 - val_loss: 0.9277 - val_accuracy: 0.7442
# Epoch 45/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1689 - accuracy: 0.9591 - val_loss: 0.7350 - val_accuracy: 0.7674
# Epoch 46/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1402 - accuracy: 0.9532 - val_loss: 0.9959 - val_accuracy: 0.6047
# Epoch 47/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1161 - accuracy: 0.9708 - val_loss: 1.4138 - val_accuracy: 0.4419
# Epoch 48/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1982 - accuracy: 0.9532 - val_loss: 1.4606 - val_accuracy: 0.4186
# Epoch 49/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1136 - accuracy: 0.9708 - val_loss: 1.0375 - val_accuracy: 0.6512
# Epoch 50/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1521 - accuracy: 0.9708 - val_loss: 2.2316 - val_accuracy: 0.6047
# Epoch 51/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1543 - accuracy: 0.9532 - val_loss: 1.1278 - val_accuracy: 0.6047
# Epoch 52/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0926 - accuracy: 0.9825 - val_loss: 1.4813 - val_accuracy: 0.3721
# Epoch 53/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1689 - accuracy: 0.9532 - val_loss: 1.6932 - val_accuracy: 0.3023
# Epoch 54/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2178 - accuracy: 0.9474 - val_loss: 1.0118 - val_accuracy: 0.5116
# Epoch 55/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1584 - accuracy: 0.9474 - val_loss: 1.1321 - val_accuracy: 0.5581
# Epoch 56/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1066 - accuracy: 0.9825 - val_loss: 1.0183 - val_accuracy: 0.6977
# Epoch 57/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0683 - accuracy: 0.9825 - val_loss: 0.8915 - val_accuracy: 0.6977
# Epoch 58/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1422 - accuracy: 0.9357 - val_loss: 0.9114 - val_accuracy: 0.7674
# Epoch 59/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.1045 - accuracy: 0.9591 - val_loss: 0.8998 - val_accuracy: 0.7209
# Epoch 60/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.1343 - accuracy: 0.9591 - val_loss: 0.7987 - val_accuracy: 0.6279
# Epoch 61/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1253 - accuracy: 0.9591 - val_loss: 1.1074 - val_accuracy: 0.5814
# Epoch 62/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1403 - accuracy: 0.9532 - val_loss: 0.7759 - val_accuracy: 0.6744
# Epoch 63/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1283 - accuracy: 0.9474 - val_loss: 0.3760 - val_accuracy: 0.8372
# Epoch 64/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0944 - accuracy: 0.9766 - val_loss: 0.7971 - val_accuracy: 0.7907
# Epoch 65/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0746 - accuracy: 0.9883 - val_loss: 0.8859 - val_accuracy: 0.6744
# Epoch 66/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0404 - accuracy: 1.0000 - val_loss: 0.9209 - val_accuracy: 0.5581
# Epoch 67/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0952 - accuracy: 0.9766 - val_loss: 0.8353 - val_accuracy: 0.6512
# Epoch 68/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1146 - accuracy: 0.9708 - val_loss: 0.6422 - val_accuracy: 0.8372
# Epoch 69/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.1091 - accuracy: 0.9708 - val_loss: 1.1724 - val_accuracy: 0.5116
# Epoch 70/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1065 - accuracy: 0.9649 - val_loss: 1.5645 - val_accuracy: 0.3721
# Epoch 71/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0936 - accuracy: 0.9649 - val_loss: 0.7681 - val_accuracy: 0.6744
# Epoch 72/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.1161 - accuracy: 0.9649 - val_loss: 0.5131 - val_accuracy: 0.7442
# Epoch 73/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2162 - accuracy: 0.9357 - val_loss: 0.2857 - val_accuracy: 0.8837
# Epoch 74/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0361 - accuracy: 1.0000 - val_loss: 0.2931 - val_accuracy: 0.8837
# Epoch 75/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0524 - accuracy: 0.9825 - val_loss: 0.3521 - val_accuracy: 0.8837
# Epoch 76/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0446 - accuracy: 0.9883 - val_loss: 0.4862 - val_accuracy: 0.8605
# Epoch 77/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1215 - accuracy: 0.9649 - val_loss: 0.5078 - val_accuracy: 0.8605
# Epoch 78/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.7925 - val_accuracy: 0.7907
# Epoch 79/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0625 - accuracy: 0.9942 - val_loss: 0.7308 - val_accuracy: 0.7442
# Epoch 80/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0617 - accuracy: 0.9825 - val_loss: 0.8804 - val_accuracy: 0.6512
# Epoch 81/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0637 - accuracy: 0.9825 - val_loss: 0.4659 - val_accuracy: 0.8140
# Epoch 82/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0726 - accuracy: 0.9883 - val_loss: 0.4956 - val_accuracy: 0.7674
# Epoch 83/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2517 - accuracy: 0.9123 - val_loss: 1.7629 - val_accuracy: 0.5116
# Epoch 84/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1377 - accuracy: 0.9649 - val_loss: 3.7409 - val_accuracy: 0.3721
# Epoch 85/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2530 - accuracy: 0.9123 - val_loss: 3.1844 - val_accuracy: 0.3953
# Epoch 86/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1587 - accuracy: 0.9532 - val_loss: 1.6319 - val_accuracy: 0.3953
# Epoch 87/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0958 - accuracy: 0.9708 - val_loss: 1.7156 - val_accuracy: 0.3488
# Epoch 88/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1056 - accuracy: 0.9766 - val_loss: 0.8105 - val_accuracy: 0.5581
# Epoch 89/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0412 - accuracy: 0.9825 - val_loss: 0.2739 - val_accuracy: 0.9535
# Epoch 90/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0645 - accuracy: 0.9825 - val_loss: 0.3410 - val_accuracy: 0.8605
# Epoch 91/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1328 - accuracy: 0.9591 - val_loss: 0.5487 - val_accuracy: 0.8372
# Epoch 92/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0662 - accuracy: 0.9825 - val_loss: 1.3753 - val_accuracy: 0.4186
# Epoch 93/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0905 - accuracy: 0.9766 - val_loss: 1.2448 - val_accuracy: 0.5581
# Epoch 94/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1591 - accuracy: 0.9532 - val_loss: 1.4848 - val_accuracy: 0.4651
# Epoch 95/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1001 - accuracy: 0.9708 - val_loss: 1.0404 - val_accuracy: 0.5349
# Epoch 96/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0881 - accuracy: 0.9649 - val_loss: 0.3245 - val_accuracy: 0.9070
# Epoch 97/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1177 - accuracy: 0.9649 - val_loss: 1.4635 - val_accuracy: 0.5581
# Epoch 98/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1525 - accuracy: 0.9649 - val_loss: 1.8302 - val_accuracy: 0.5116
# Epoch 99/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1207 - accuracy: 0.9766 - val_loss: 0.9802 - val_accuracy: 0.6977
# Epoch 100/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0551 - accuracy: 0.9766 - val_loss: 0.6151 - val_accuracy: 0.6744
# Epoch 101/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.1243 - accuracy: 0.9766 - val_loss: 1.3391 - val_accuracy: 0.6047
# Epoch 102/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0532 - accuracy: 0.9825 - val_loss: 0.7877 - val_accuracy: 0.7674
# Epoch 103/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0780 - accuracy: 0.9825 - val_loss: 0.6232 - val_accuracy: 0.8605
# Epoch 104/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0727 - accuracy: 0.9825 - val_loss: 1.0197 - val_accuracy: 0.6977
# Epoch 105/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1206 - accuracy: 0.9649 - val_loss: 0.5010 - val_accuracy: 0.8372
# Epoch 106/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0566 - accuracy: 0.9883 - val_loss: 0.4692 - val_accuracy: 0.7674
# Epoch 107/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0305 - accuracy: 0.9942 - val_loss: 0.9284 - val_accuracy: 0.7209
# Epoch 108/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0886 - accuracy: 0.9532 - val_loss: 0.6645 - val_accuracy: 0.7442
# Epoch 109/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0385 - accuracy: 0.9825 - val_loss: 0.1149 - val_accuracy: 1.0000
# Epoch 110/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1397 - accuracy: 0.9649 - val_loss: 0.1520 - val_accuracy: 1.0000
# Epoch 111/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0504 - accuracy: 0.9883 - val_loss: 3.1053 - val_accuracy: 0.6047
# Epoch 112/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1156 - accuracy: 0.9649 - val_loss: 4.9872 - val_accuracy: 0.6279
# Epoch 113/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2468 - accuracy: 0.9181 - val_loss: 0.6808 - val_accuracy: 0.7907
# Epoch 114/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1718 - accuracy: 0.9591 - val_loss: 2.7594 - val_accuracy: 0.5814
# Epoch 115/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0899 - accuracy: 0.9766 - val_loss: 0.4825 - val_accuracy: 0.8140
# Epoch 116/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1551 - accuracy: 0.9591 - val_loss: 0.8591 - val_accuracy: 0.6977
# Epoch 117/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1034 - accuracy: 0.9708 - val_loss: 1.8744 - val_accuracy: 0.6279
# Epoch 118/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1326 - accuracy: 0.9766 - val_loss: 1.1622 - val_accuracy: 0.5581
# Epoch 119/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0965 - accuracy: 0.9766 - val_loss: 0.6741 - val_accuracy: 0.7442
# Epoch 120/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0439 - accuracy: 0.9883 - val_loss: 0.7265 - val_accuracy: 0.6977
# Epoch 121/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0636 - accuracy: 0.9883 - val_loss: 0.7754 - val_accuracy: 0.7442
# Epoch 122/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1320 - accuracy: 0.9766 - val_loss: 0.9171 - val_accuracy: 0.5814
# Epoch 123/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0776 - accuracy: 0.9766 - val_loss: 0.8994 - val_accuracy: 0.5814
# Epoch 124/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0419 - accuracy: 0.9883 - val_loss: 0.7729 - val_accuracy: 0.8140
# Epoch 125/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0918 - accuracy: 0.9766 - val_loss: 0.5383 - val_accuracy: 0.7907
# Epoch 126/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0236 - accuracy: 0.9942 - val_loss: 0.7600 - val_accuracy: 0.6744
# Epoch 127/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0272 - accuracy: 0.9942 - val_loss: 0.6012 - val_accuracy: 0.6977
# Epoch 128/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0333 - accuracy: 0.9942 - val_loss: 0.4779 - val_accuracy: 0.7674
# Epoch 129/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.4404 - val_accuracy: 0.8605
# Epoch 130/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.4303 - val_accuracy: 0.8372
# Epoch 131/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0691 - accuracy: 0.9825 - val_loss: 0.2620 - val_accuracy: 0.9302
# Epoch 132/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0715 - accuracy: 0.9825 - val_loss: 0.2378 - val_accuracy: 0.8837
# Epoch 133/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0657 - accuracy: 0.9883 - val_loss: 0.4105 - val_accuracy: 0.8140
# Epoch 134/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2754 - accuracy: 0.9181 - val_loss: 0.9470 - val_accuracy: 0.7674
# Epoch 135/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.1059 - accuracy: 0.9708 - val_loss: 0.5671 - val_accuracy: 0.6977
# Epoch 136/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1509 - accuracy: 0.9649 - val_loss: 0.6578 - val_accuracy: 0.6977
# Epoch 137/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0281 - accuracy: 0.9883 - val_loss: 0.9214 - val_accuracy: 0.6744
# Epoch 138/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0669 - accuracy: 0.9825 - val_loss: 0.5032 - val_accuracy: 0.7907
# Epoch 139/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0816 - accuracy: 0.9883 - val_loss: 0.0852 - val_accuracy: 0.9767
# Epoch 140/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0728 - accuracy: 0.9766 - val_loss: 0.1405 - val_accuracy: 0.9302
# Epoch 141/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0632 - accuracy: 0.9825 - val_loss: 0.0657 - val_accuracy: 0.9767
# Epoch 142/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0358 - accuracy: 0.9942 - val_loss: 0.2081 - val_accuracy: 0.9070
# Epoch 143/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.1050 - accuracy: 0.9708 - val_loss: 0.1430 - val_accuracy: 0.9535
# Epoch 144/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0581 - accuracy: 0.9766 - val_loss: 0.5867 - val_accuracy: 0.7907
# Epoch 145/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0424 - accuracy: 0.9766 - val_loss: 0.0826 - val_accuracy: 0.9535
# Epoch 146/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0717 - accuracy: 0.9825 - val_loss: 0.5712 - val_accuracy: 0.7907
# Epoch 147/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1272 - accuracy: 0.9474 - val_loss: 0.5168 - val_accuracy: 0.8140
# Epoch 148/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0710 - accuracy: 0.9825 - val_loss: 0.6630 - val_accuracy: 0.7674
# Epoch 149/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0399 - accuracy: 0.9942 - val_loss: 0.4219 - val_accuracy: 0.8605
# Epoch 150/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0586 - accuracy: 0.9883 - val_loss: 0.1403 - val_accuracy: 0.9767
# Epoch 151/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0895 - accuracy: 0.9708 - val_loss: 1.5136 - val_accuracy: 0.7674
# Epoch 152/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2890 - accuracy: 0.9123 - val_loss: 2.3118 - val_accuracy: 0.5581
# Epoch 153/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1844 - accuracy: 0.9357 - val_loss: 4.6355 - val_accuracy: 0.4419
# Epoch 154/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0775 - accuracy: 0.9708 - val_loss: 10.7083 - val_accuracy: 0.3721
# Epoch 155/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1059 - accuracy: 0.9825 - val_loss: 3.8199 - val_accuracy: 0.5349
# Epoch 156/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1723 - accuracy: 0.9415 - val_loss: 4.1389 - val_accuracy: 0.5814
# Epoch 157/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0624 - accuracy: 0.9766 - val_loss: 3.2326 - val_accuracy: 0.5814
# Epoch 158/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0515 - accuracy: 0.9825 - val_loss: 2.1310 - val_accuracy: 0.6047
# Epoch 159/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.4776 - val_accuracy: 0.8140
# Epoch 160/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0312 - accuracy: 0.9942 - val_loss: 0.2012 - val_accuracy: 0.9070
# Epoch 161/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0550 - accuracy: 0.9825 - val_loss: 0.1447 - val_accuracy: 0.9535
# Epoch 162/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0253 - accuracy: 0.9942 - val_loss: 0.2725 - val_accuracy: 0.9070
# Epoch 163/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0365 - accuracy: 0.9883 - val_loss: 0.6795 - val_accuracy: 0.7907
# Epoch 164/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0648 - accuracy: 0.9766 - val_loss: 0.4447 - val_accuracy: 0.8372
# Epoch 165/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0312 - accuracy: 0.9883 - val_loss: 0.4228 - val_accuracy: 0.8140
# Epoch 166/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.1218 - accuracy: 0.9883 - val_loss: 0.3244 - val_accuracy: 0.9070
# Epoch 167/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1192 - accuracy: 0.9591 - val_loss: 0.4270 - val_accuracy: 0.8372
# Epoch 168/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0968 - accuracy: 0.9708 - val_loss: 2.7760 - val_accuracy: 0.5814
# Epoch 169/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1597 - accuracy: 0.9240 - val_loss: 1.9895 - val_accuracy: 0.6512
# Epoch 170/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.1432 - accuracy: 0.9532 - val_loss: 0.8333 - val_accuracy: 0.7442
# Epoch 171/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0873 - accuracy: 0.9591 - val_loss: 1.3707 - val_accuracy: 0.6977
# Epoch 172/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.1026 - accuracy: 0.9708 - val_loss: 0.9220 - val_accuracy: 0.6977
# Epoch 173/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0513 - accuracy: 0.9825 - val_loss: 0.9129 - val_accuracy: 0.6977
# Epoch 174/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0778 - accuracy: 0.9825 - val_loss: 0.7565 - val_accuracy: 0.7209
# Epoch 175/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0237 - accuracy: 0.9883 - val_loss: 0.5696 - val_accuracy: 0.8140
# Epoch 176/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.5645 - val_accuracy: 0.8372
# Epoch 177/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.4979 - val_accuracy: 0.8372
# Epoch 178/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0376 - accuracy: 0.9883 - val_loss: 0.4997 - val_accuracy: 0.7674
# Epoch 179/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0312 - accuracy: 0.9942 - val_loss: 0.4221 - val_accuracy: 0.8372
# Epoch 180/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0232 - accuracy: 0.9942 - val_loss: 0.3056 - val_accuracy: 0.8372
# Epoch 181/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0330 - accuracy: 0.9883 - val_loss: 0.2105 - val_accuracy: 0.9302
# Epoch 182/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0515 - accuracy: 0.9883 - val_loss: 0.2692 - val_accuracy: 0.9302
# Epoch 183/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0190 - accuracy: 0.9942 - val_loss: 0.9036 - val_accuracy: 0.6977
# Epoch 184/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0628 - accuracy: 0.9708 - val_loss: 0.6397 - val_accuracy: 0.7674
# Epoch 185/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0531 - accuracy: 0.9883 - val_loss: 0.1271 - val_accuracy: 0.9535
# Epoch 186/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0436 - accuracy: 0.9883 - val_loss: 0.5090 - val_accuracy: 0.8837
# Epoch 187/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0884 - accuracy: 0.9766 - val_loss: 0.1144 - val_accuracy: 0.9535
# Epoch 188/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0184 - accuracy: 0.9942 - val_loss: 0.1692 - val_accuracy: 0.9535
# Epoch 189/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0221 - accuracy: 0.9883 - val_loss: 0.4678 - val_accuracy: 0.8140
# Epoch 190/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0619 - accuracy: 0.9766 - val_loss: 0.4003 - val_accuracy: 0.7674
# Epoch 191/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0333 - accuracy: 0.9883 - val_loss: 1.0126 - val_accuracy: 0.6512
# Epoch 192/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0366 - accuracy: 0.9825 - val_loss: 0.9741 - val_accuracy: 0.7209
# Epoch 193/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0783 - accuracy: 0.9766 - val_loss: 0.7405 - val_accuracy: 0.8140
# Epoch 194/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0507 - accuracy: 0.9825 - val_loss: 0.4396 - val_accuracy: 0.8605
# Epoch 195/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0439 - accuracy: 0.9883 - val_loss: 0.9252 - val_accuracy: 0.6977
# Epoch 196/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0309 - accuracy: 0.9883 - val_loss: 0.3599 - val_accuracy: 0.9070
# Epoch 197/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.1735 - val_accuracy: 0.9302
# Epoch 198/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0829 - accuracy: 0.9766 - val_loss: 0.1238 - val_accuracy: 0.9535
# Epoch 199/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0380 - accuracy: 0.9825 - val_loss: 0.3189 - val_accuracy: 0.9070
# Epoch 200/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0571 - accuracy: 0.9825 - val_loss: 1.7199 - val_accuracy: 0.7209

# %%
model.save("sign_language_lstm.h5")
np.save("actions.npy", actions)
# Out:
# C:\Users\kongm\PycharmProjects\SignLanguage\.venv3\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# ===============================
# MEDIA PIPE SETUP
# ===============================
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

# ===============================
# LOAD MODEL & ACTIONS
# ===============================
model = tf.keras.models.load_model("sign_language_lstm.h5")
actions = np.load("actions.npy", allow_pickle=True)

# ===============================
# KEYPOINT EXTRACTION (HANDS ONLY)
# ===============================
def extract_hand_keypoints(results):
    """Extract only left and right hand keypoints (21 points each)"""
    lh = np.zeros(21*3)
    rh = np.zeros(21*3)

    if results.left_hand_landmarks:
        lh = np.array([[lm.x, lm.y, lm.z] for lm in results.left_hand_landmarks.landmark]).flatten()
    if results.right_hand_landmarks:
        rh = np.array([[lm.x, lm.y, lm.z] for lm in results.right_hand_landmarks.landmark]).flatten()

    return np.concatenate([lh, rh])  # total 126 features

# ===============================
# CAMERA SETUP
# ===============================
cap = cv2.VideoCapture(0)
cap.set(3, 1280)
cap.set(4, 720)

sequence = []
last_action = ""
threshold = 0.9  # confidence threshold

# ===============================
# REAL-TIME PREDICTION LOOP
# ===============================
with mp_holistic.Holistic(min_detection_confidence=0.5,
                          min_tracking_confidence=0.5) as holistic:

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Convert BGR to RGB for MediaPipe
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = holistic.process(image)

        # Draw only hands on frame
        if results.left_hand_landmarks:
            mp_drawing.draw_landmarks(frame, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
        if results.right_hand_landmarks:
            mp_drawing.draw_landmarks(frame, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

        # Check if any hand is detected
        hands_present = results.left_hand_landmarks or results.right_hand_landmarks

        if hands_present:
            # Extract keypoints and add to sequence
            keypoints = extract_hand_keypoints(results)
            sequence.append(keypoints)
            sequence = sequence[-30:]  # keep last 30 frames

            # Predict only if sequence is full
            if len(sequence) == 30:
                pred = model.predict(np.expand_dims(sequence, axis=0), verbose=0)[0]
                max_confidence = np.max(pred)
                predicted_action = actions[np.argmax(pred)]

                if max_confidence > threshold:
                    last_action = predicted_action
                else:
                    last_action = ""  # clear action if confidence too low
        else:
            # No hands detected: clear sequence and last action
            sequence = []
            last_action = ""

        # Display action if available
        if last_action != "":
            cv2.putText(frame, f"{last_action}", (50, 100),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 0), 3)

        # Show frame
        cv2.imshow("Sign Recognition", frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
cv2.destroyAllWindows()
